# %%
test_str = "function transferFrom(address from, address to, uint tokens) public returns (bool success) { balances[from] = safeSub(balances[from], tokens); allowed[from][msg.sender] = safeSub(allowed[from][msg.sender], tokens); balances[to] = safeAdd(balances[to], tokens); Transfer(from, to, tokens); return true; }function transfer(address to, uint tokens) public returns (bool success) { balances[msg.sender] = safeSub(balances[msg.sender], tokens); balances[to] = safeAdd(balances[to], tokens); Transfer(msg.sender, to, tokens); return true; } "

# %%
# !pip install transformers torch datasets lightgbm torchvision
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %% [markdown]
# # Первый вариант

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from torch import nn

model = AutoModelForSequenceClassification.from_pretrained("./best-src-pt-checkpoint")
model_emb = AutoModelForSequenceClassification.from_pretrained("./best-src-pt-checkpoint")
model_emb.classifier = nn.Identity()

tokenizer = AutoTokenizer.from_pretrained("./tokenizer")

# %%
import torch
import numpy as np

with torch.no_grad():
    in_str = tokenizer(test_str, truncation=True, padding=True, max_length=512, return_tensors="pt")
    res = model(**in_str)
    probs = torch.sigmoid(res.logits[0])
    pos = torch.argmax(probs)

(pos,probs[pos])
# Out:
# (tensor(1), tensor(0.7027))

# %% [markdown]
# # С дополнением

# %%
with torch.no_grad():
    in_str = tokenizer(test_str, truncation=True, padding=True, max_length=512, return_tensors="pt")
    emb = model_emb(**in_str).logits[0].numpy()
    ans = emb

#model_2.predict_proba()
ans
# Out:
# array([ 5.12974679e-01, -1.09788775e-01, -4.34133895e-02,  7.47513711e-01,
#         3.67920846e-01,  2.62939278e-02,  1.14551932e-01,  3.72093208e-02,
#        -1.07977130e-01,  3.17177862e-01,  5.37970066e-01, -1.58392057e-01,
#        -9.88741145e-02, -6.17659763e-02, -1.27623662e-01, -1.63799167e-01,
#         3.75791676e-02,  3.72809246e-02, -1.69762820e-01, -1.03996128e-01,
#        -2.11716779e-02,  3.95361274e-01,  6.14257276e-01,  6.90478683e-02,
#         2.36930937e-01,  7.40353167e-01, -5.84414788e-03,  3.40364307e-01,
#        -9.90795270e-02, -6.15104623e-02,  3.45303118e-02, -1.64681152e-01,
#         3.07758510e-01,  3.78829867e-01,  3.30384523e-01,  7.14544475e-01,
#        -1.76000167e-02, -1.64616093e-01,  6.05039895e-01,  7.27650570e-03,
#        -1.69071138e-01,  3.62428933e-01,  2.63066560e-01, -1.58484533e-01,
#        -8.44565108e-02, -1.38910815e-01, -7.10644498e-02,  4.40679848e-01,
# ...

# %%
import numpy as np
ans = np.array(
    [ 5.12974679e-01, -1.09788775e-01, -4.34133895e-02,  7.47513711e-01,
        3.67920846e-01,  2.62939278e-02,  1.14551932e-01,  3.72093208e-02,
       -1.07977130e-01,  3.17177862e-01,  5.37970066e-01, -1.58392057e-01,
       -9.88741145e-02, -6.17659763e-02, -1.27623662e-01, -1.63799167e-01,
        3.75791676e-02,  3.72809246e-02, -1.69762820e-01, -1.03996128e-01,
       -2.11716779e-02,  3.95361274e-01,  6.14257276e-01,  6.90478683e-02,
        4.24717456e-01, -1.55956596e-01,  3.60255390e-02,  1.43909296e-02,
       -1.04090953e-02,  9.68642890e-01, -6.09250069e-02,  4.68788967e-02,
        8.99748653e-02,  1.47363320e-01, -1.66608602e-01, -2.34435014e-02,
        5.32593802e-02,  3.75913858e-01, -1.23801567e-01,  1.51823625e-01,
        3.88999283e-01,  1.11012244e+00,  7.73491263e-01,  9.92944181e-01,
        7.48817176e-02,  2.16472641e-01,  1.96634248e-01,  6.98017180e-01,
        2.98787624e-01, -1.50459468e-01,  2.36820400e-01,  2.37006351e-01,
        3.24992895e-01,  8.36053118e-02,  3.27314496e-01, -8.79336521e-02,
       -1.15748480e-01, -1.52953565e-01,  3.93208601e-02, -3.90291400e-02,
        5.31502366e-01, -1.67076975e-01,  2.79736996e-01, -1.34689987e-01,
        2.45163277e-01,  7.81230107e-02, -2.72862595e-02, -5.39627075e-02]
     )

# %%
ans
# Out:
# array([ 5.12974679e-01, -1.09788775e-01, -4.34133895e-02,  7.47513711e-01,
#         3.67920846e-01,  2.62939278e-02,  1.14551932e-01,  3.72093208e-02,
#        -1.07977130e-01,  3.17177862e-01,  5.37970066e-01, -1.58392057e-01,
#        -9.88741145e-02, -6.17659763e-02, -1.27623662e-01, -1.63799167e-01,
#         3.75791676e-02,  3.72809246e-02, -1.69762820e-01, -1.03996128e-01,
#        -2.11716779e-02,  3.95361274e-01,  6.14257276e-01,  6.90478683e-02,
#         2.36930937e-01,  7.40353167e-01, -5.84414788e-03,  3.40364307e-01,
#        -9.90795270e-02, -6.15104623e-02,  3.45303118e-02, -1.64681152e-01,
#         3.07758510e-01,  3.78829867e-01,  3.30384523e-01,  7.14544475e-01,
#        -1.76000167e-02, -1.64616093e-01,  6.05039895e-01,  7.27650570e-03,
#        -1.69071138e-01,  3.62428933e-01,  2.63066560e-01, -1.58484533e-01,
#        -8.44565108e-02, -1.38910815e-01, -7.10644498e-02,  4.40679848e-01,
# ...

# %%
import pickle
with open('./LGBMClassifier.pkl', 'rb') as f:
    boosting = pickle.load(f)
boosting
# Out:
# /Users/maksim/anaconda3/envs/sber_hack/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# LGBMClassifier(bagging_fraction=0.5239746723663514, bagging_freq=6,
#                boosting_type='dart', feature_fraction=0.7450200644139781,
#                lambda_l1=0.5106800157602552, lambda_l2=0.015759197733137425,
#                learning_rate=0.05901201580365878, max_depth=12,
#                min_child_samples=17, n_estimators=196, num_leaves=94)

# %%
boosting.predict_proba(ans.reshape(1,-1))[:,1]
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.5106800157602552, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.5106800157602552
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=0.7450200644139781, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7450200644139781
# [LightGBM] [Warning] bagging_fraction is set=0.5239746723663514, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5239746723663514
# [LightGBM] [Warning] lambda_l2 is set=0.015759197733137425, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.015759197733137425
# array([0.97132878])
